# %% [markdown]
# Dependencies
#
# docx: pip install python-docx
#
# PyPDF2: pip install pypdf2
#
# NLTK  : pip install -U nltk

# %%
import glob2
import docx
from docx import Document
import PyPDF2
import csv
import nltk
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
#Check if have download all needed additional data for nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\maxpr/nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to C:\Users\maxpr/nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\maxpr/nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to C:\Users\maxpr/nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %% [markdown]
# ### Openning files

# %%
keppels_files = glob2.glob('files/Keppel/*')
prudential_files = glob2.glob('files/Prudential/*')
print(f'we have {len(keppels_files)} keppels documents and {len(prudential_files)} Prudential documents')
# Out:
# we have 193 keppels documents and 194 Prudential documents

# %% [markdown]
# Let's check the percentage of different document type

# %%
keppels_files_pdf = glob2.glob('files/Keppel/*.pdf')
keppels_files_xls = glob2.glob('files/Keppel/*.xlsx') + glob2.glob('files/Keppel/*.xls')
keppels_files_doc = glob2.glob('files/Keppel/*.docx') + glob2.glob('files/Keppel/*.doc')
len(keppels_files_pdf) + len(keppels_files_xls) + len(keppels_files_doc)
# Out:
# 193

# %%
prudential_files_pdf = glob2.glob('files/Prudential/*.pdf')
prudential_files_xls = glob2.glob('files/Prudential/*.xlsx') + glob2.glob('files/Prudential/*.xls')
prudential_files_doc = glob2.glob('files/Prudential/*.docx') + glob2.glob('files/Prudential/*.doc')
len(prudential_files_pdf) + len(prudential_files_xls) + len(prudential_files_doc)
# Out:
# 194

# %% [markdown]
# From that we can conclude that the documents are of three different types (pdf, word and excel)

# %%
doc = Document(keppels_files_doc[0])
def getText(filename):
    doc = docx.Document(filename)
    fullText = []
    for para in doc.paragraphs:
        fullText.append(para.text)
    return '\n'.join(fullText)

# %%
print(f'File {keppels_files_doc[3]} content is :')
print((getText(keppels_files_doc[3])))
# Out:
# File files/Keppel\CYP%20Meeting%20May%202017docx.docx content is :
# CHILDREN AND YOUNG PEOPLE NETWORK
# 18.05.2017 at London Funders
#
# Participants
#          Deborah	Meyer	Big Lottery Fund
# 	Toyin	Ogundana	CAF Venturesome
# 	Daisy	Ryan	Henry Smith Charity
# 	Erik	Mesel	John Lyon's Charity
# 	Sharon	Long	Partnership For Young London
# 	Mihai	Calin Bica	Roma Support Group
# 	Gaba	Smolinska-	Roma Support Group
# 	Poffley
# 	Victoria	Cousins	Safer London Foundation
# 	Cara	Whelan	Save the Children
# 	Emma	Hale	Sir John Cass's Foundation
# 	Rachel	Earnshaw	The Big Give
# 	Ciaran	Rafferty	The City Bridge Trust
# 	Jenny	Oppenheimer	The Pilgrim Trust
# 	Patrick	Kinsella	Traveller Movement
# 	Yvonne	MacNamara	Traveller Movement
# 	Flora	Ward	Youth Music
#
# In attendance
#          Geraldine	Tovey	London Funders
# 	David	Warner	London Funders
#
# Welcome and apologies for absence
#
# Ciaran welcomed everyone to the group and introductions were made. He welcomed the group to its first network meeting in 2017 following the Vision for Young Londoners event earlier in the year.
#
# Report of last meeting, 30th November 2016
#
# Minutes from the last Children and Young People’s meeting were agreed.
#
# Yvonne MacNamara and Patrick Kinsella- Traveller Movement
#
# The Traveller Movement is a small charity based in London but with a national remit. It focuses on building bridges between organisations working with the traveller community. Its aim is for greater inclusion, civic engagement and community cohesion. Below are the main outputs of The Traveller Movement
#
# Equality and Social Justice Unit- there are 3 specific strands to this: 1. Early action and capacity building, 2. Strategic litigation e.g. the 2015 Wetherspoon litigation case, 3. Capacity building of frontline service providers
# Community led training projects- with a focus on ‘train the trainer’
# Education advocacy and training- this focuses on school exclusions, bullying and parental support.
# Community advocacy
# Domestic violence- this work is done in partnership with Solace Women’s Aid to provide advocacy and training. The Traveller Movement is currently running a 12 week advocacy course for women in the community.
# Policy & research- across all social indicators. The Traveller Movement is currently focusing on criminal justice and health and wellbeing
#
# Gypsies and Travellers in criminal justice: Context
#
# There is a more accurate picture of the percentage of Gypsies and Travellers (GRT) in the adult prison estate due to different data collection and monitoring than in the youth justice sector, based on the 2011 census. The figures below are still likely to be inaccurate because some prisoners may be reluctant to share their ethnicity. This is changing as there are increasing benefits to self-identifying.
# 5% adult male prison estate
# 6% adult female prison estate
# Worse outcomes and worse experiences of custody
#
# GRT are less likely to be involved in purposeful activity within the adult prison estate. This is not because of fecklessness or because they are unwilling. It is because of rules within the estate which prevent them from being able to work: you need to have Level 2 Basic English to have a job or take part in vocational training. Furthermore, literacy classes are often not appropriate for adults.
#
# Below are figures relating to the number of GRT children in the youth justice system.
# 12% in Secure Training Centres (15% of girls)
# 7% in Young Offender Institutions
# Numbers almost certainly higher- for example the Keppel Unit  for vulnerable boys in Wetherby has estimated 17% of its population come from the traveller community
#
# The 2011 census included a GRT category for the first time. This estimated that 55,000 people in the UK come from this background (although the figure is likely to be a lot higher). Regardless, it is clear that the GRT population is overrepresented in the custodial system.
#
# As well as being overrepresented, the GRT community is also overlooked in reporting.
#
# No mention in the Charlie Taylor review into youth justice- despite input from the community into this report
# No mention in the initial findings of the Lammy Review- despite input from the community into this report
# No mention in the Clinks/Lord Farmer Review
# No mention in latest Sentencing Guidelines
# No mention (so far) in criminalisation of children in care
# Reduced emphasis in latest Children in Custody
#
# The Traveller Movement is hopeful that being from a GRT background will be included in sentencing guidelines sooner rather than later. Below are shared characteristics within the community
#
# Mental health issues & vulnerability to self-harm- the GRT community is 2-3x more likely to self-harm than the average UK citizen
# Learning difficulties- the highest SEN rates of all ethnic minority groups
# Traumatic life experiences: Loss, neglect and abuse- increasing prevalence of substance abuse (40% YOI drug) – alcoholism shown to be a coping mechanism; 10-12 lower life expectancy & high suicide rate means loss of parent common; infant mortality rate higher –loss of siblings; high prevalence of DV (61% Gypsy and 81% Irish Traveller)
# Local authority care- 47% of children from the community in secure training centres have been in care.
# Negative experience of authority- the Traveller Movement’s research suggests 98% have experienced discrimination because of ethnicity; exclusion discriminatory (perceived) policing = distrust.
#
# Overrepresented & Overlooked: Gypsy Traveller and Roma children in the youth justice system
# The report foreword was written by Kate Green MP, who has also helped to publicise the report and initiate a Westminster Hall debate.
# The report’s primary aim is to get ethnic monitoring for the GRT community in the youth justice system. This will help to address the issue of children falling along the way and unmet mental health needs.
# Secure Training Centres- statistics of young gypsies/travellers
# Local authority care: 47% had been in local authority care (compared with 37% non-GRT)
# Found it significantly more difficult to maintain contact with support networks- 60% said it was easy compared to 90% non-GRT
# Twice as likely to report unmet health needs
# Significantly less likely to report learning skills for jobs they’d like to do in future
# Safety: 3x greater reports of physical abuse from staff & 5x more likely to report having their property taken by other children
# Young Offenders Institutions- statistics of young gypsies/travellers
#
# 33% had been in local authority care. This has decreased from 44% in 2015 but still very high
# Less likely to say it was their first time custody- 51% compared to 61% - also 31% sentenced to 12 months <
# 40% had a problem with drugs when they first arrived
# A quarter reported mental health issues – less than half said they were being helped for this issue
# 55% had been 14 or younger when they were last in school & 84% had been excluded
# Less likely to know who to contact for help in opening a bank account and continuing health services when released
# One in ten people from the community in Young Offenders Institutions has a child.
#
# What next? How can services be improved?
#
# Good practice guide- in particular custody is ineffective, there is a prevalence of reoffending and an overall lack of support.
# Culturally appropriate learning resources- a programme aimed for GRT (perhaps with an emphasis on trade) and other non-literate offenders would be beneficial. This should be a twin-pronged approach with mentoring.
# Support for GRT groups: lessons from adult estate where this has been implemented. Support groups provide safe-spaces and create a more positive outlook.
# Improve participation in education and purposeful activity
#
# Summary of further support needed beyond custody
#
# Overall an analysis of why children go into custody is needed. Is there more to it than education/training? Early intervention such as building community advocacy is also important. Notwithstanding the GRT culture needs to be understood and respected.
#
# There is a real need for targeted funding for initiatives such as advocacy support (and for other marginalised communities too). There are often language and cultural barriers preventing the GRT community from accessing standard advocacy services. For instance families contact GRT organisations when care proceedings are already at the ‘11th hour’. Once children are placed in foster care, they are likely to be placed for adoption. Kinship care is less likely to be offered to the GRT community.
#
# It is important for funders to invest in training and capacity building and to ensure that GRT is included in reporting. Long term (3-5 year) funding for sustainability is needed. Many pilots are funded and then not continued- causing information to be lost. It is also important to encourage partnership working and campaign to change the language used in the VCS and public sector. Reciprocal training is also useful- it is important that GRT issues are known about more widely within the sector.
#
# Overall difficulties facing GRT groups are not impossible to overcome. Inreach is needed instead of outreach. The success of some Somali projects show how progress can be made.
#
#
# Gaba Smolinska-Poffley- Roma Support Group
#
# The RSG is a registered charity and a company limited by guarantee. The organisation has 19 years’ experience working with the Roma communities and supporting professionals and services across the UK Established by Roma, and it is led by them today. The RSG delivers services to East European Roma refugee and migrant families in London. The organisation is responsive to the needs of clients and tries to share as much learning with professionals as possible.
#
# Who are the Roma?
#
# Roma originate from Northwest India. Migration began over 1,000 years ago. For not known reasons Roma travelled through Asia, North Africa, Europe and Americas before settling mainly in Eastern Europe.
#
# There are many different Roma groups speaking many different Romany dialects- the three biggest groups are Polish, Slovak and Romanian. There are approximately 12 million Roma globally.
#
# Roma in the UK
#
# There has been widespread discrimination of Roma in Eastern Europe, leading them to try and establish a better life in the UK. Issues facing Roma in Eastern Europe included segregated education and even forced sterilisation. Migration increased with the expansion of EU member countries in the mid-2000s. There are Roma in most London boroughs, and in particular in East London.
#
# In the UK there are different groups: Gypsy, Roma, Travellers (GRT). There are similar problems they all face e.g. welfare problems, low life expectancy, low achievement in education and experience of discrimination. However they have different cultural identities and lifestyle. Roma tend to prefer living in brick and mortar houses and migration tends to involve whole communities.
#
# There is very little data available which provides a reliable estimate of Roma living in the UK; University of Salford’s report “Migrant Roma in the UK”, published in October 2013, estimated 200,000 Roma living in the UK.
#
# Discrimination
#
# Although Roma are the largest ethnic group without their own state in Europe, they are worse off than most other ethnic groups when it comes to employment, education, health and political participation:
#
# Social and economic disadvantage: exclusion from mainstream society and disproportionate levels of long term unemployment leading to child poverty, destitution and homelessness. Housing problems (e.g. overcrowding, community tension with landlords) and poverty are worse in London.
# There are a growing number of Roma families in child protection procedures. There is a limited provision of advocacy and a limited ability for the Roma population to access information on child protection, safeguarding and other laws.
# Education: Segregated education in countries of origin - lowest educational attainment of all ethnic groups in the UK. Less than 40% of Roma children get 5 good GCSEs. Roma children are more likely to experience bullying, have attendance issues and behaviour problems.
# Health: Discrimination in access to health provision - the Council of Europe states that life expectancy of Roma is in general 8-15 years lower and the mortality, infections and chronic disease rates are much higher. Substance misuse is also an issue prevalent in the community.
# Political participation of Roma is still at a very low level, with only one Roma Member of the European Parliament
#
# Roma tend to move home regularly. This often affects and limits access to healthcare, education and further community engagement. The Roma Support Group is trying to respond to the needs of the community and is campaigning for better advocacy overall. It is training ‘Roma Champions’ to deliver training and explain to professionals the barriers which the community faces. They are also promoting raising the aspirations of young people and the value of education overall.
#
# Brexit and its effects on the Roma Community
#
# The rights of Roma in the UK are not secure following the referendum. Many Roma are not British citizens and are now scared/unwilling to apply for welfare and other support.
#
# There has been an increase in homophobic and racially motivated incidents (e.g. incidents in schools)
# Stress, anxiety and fears about the future
# Lack of information
# Responses/actions of authorities (e.g. re-entry into UK and removals)
# Applications for benefits and Permanent Right to Reside
# Voluntary sector unprepared – lack of resources
#
# Overall there is a lack of quality information and services for the Roma community. Funders need to be more aware that the Roma community are as acutely discriminated as other BME groups. Discrimination against the GRT community is one of the last acceptable prejudices.
#
# Face-to-face training is needed alongside toolkits and online support. Funding to deliver training is vital, especially to frontline workers. Conversations are needed to challenge existing practice.
#
# Q&A and group discussion
#
# London Funders is looking at scheduling a meeting with the London Safeguarding board looking at the role of funders in safeguarding. Children in Need are also developing an initiative in this area.
# London Funders is also talking to Street Doctors about future work.
# CAF Venturesome is the social investment arm of CAF.  It has a fund for CYP projects supported by philanthropists and trusts. It also has a repayable loan scheme.
# City Bridge Trust has just announced a large £4.5 million package for funding and support to help disabled young people into support. It will offer money for paid work experience/internships for a fixed, fairly lengthy time. It is looking to influence policy and practice in the long term.
# Big Lottery has just awarded youth investment fund grants in East London.
# The GLA is doing lots of work to get a buy-in for the Vision for Young Londoners and to develop more infrastructure for children and young people. There is a possibility for additional funding for summer activities. MOPAC in particular is concerned about the rise of knife crimes over the summer and is looking to consult with the independent funding community.
#
# Lastly, Ciaran thanked everyone for attending his last meeting as chair of the Children and Young People group. He stated that it has been a privilege to be chair and to watch the group grow, develop and collaborate. A turning point for the CYP group was inviting non-funders and frontline organisations to share their knowledge. Sara Masters from the Mercers Company will be taking over as London Funders Chair.
#
# Date of next meeting
#
# TBD

# %%
#keep : no not don't aren't aren
ourStopWord = ['i', 'me', 'my', 'myself', 'we', 'our','I',
               'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your',
               'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her',
               'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs',
               'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those',
               'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do',
               'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until',
               'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through',
               'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on',
               'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where',
               'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such',
                'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will',
               'just','should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y',
                'ma' ]

# %%
def removeStop(text):
    stop_words = ourStopWord
 
    word_tokens = word_tokenize(text)
 
    #filtered_sentence = [w for w in word_tokens if not w in stop_words]
 
    filtered_sentence = []
 
    for w in word_tokens:
        #w = w.lower()
        if w not in stop_words:
            if (w=="n\'t"):
                w="not"
            filtered_sentence.append(w)
    return filtered_sentence

# %%
text = removeStop(getText(keppels_files_doc[3]))

# %%
def textPOS(text):
    #text = [c.lower() for c in text]
    return nltk.pos_tag(text)

# %%
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return ''

# %%
textCleaned = removeStop(getText(keppels_files_doc[3]))

# %%
textPOS = textPOS(textCleaned)

# %%
textPOS[100:1000]
# Out:
# [('Funders', 'NNP'),
#  ('Welcome', 'NNP'),
#  ('apologies', 'NNS'),
#  ('absence', 'NN'),
#  ('Ciaran', 'NNP'),
#  ('welcomed', 'VBD'),
#  ('everyone', 'NN'),
#  ('group', 'NN'),
#  ('introductions', 'NNS'),
#  ('made', 'VBD'),
#  ('.', '.'),
#  ('He', 'PRP'),
#  ('welcomed', 'VBD'),
#  ('group', 'NN'),
#  ('first', 'RB'),
#  ('network', 'NN'),
#  ('meeting', 'NN'),
#  ('2017', 'CD'),
#  ('following', 'VBG'),
#  ('Vision', 'NNP'),
#  ('Young', 'NNP'),
#  ('Londoners', 'NNPS'),
#  ('event', 'NN'),
#  ('earlier', 'RB'),
#  ('year', 'NN'),
#  ('.', '.'),
#  ('Report', 'NNP'),
#  ('last', 'JJ'),
#  ('meeting', 'NN'),
#  (',', ','),
#  ('30th', 'CD'),
#  ('November', 'NNP'),
#  ('2016', 'CD'),
#  ('Minutes', 'NNP'),
#  ('last', 'JJ'),
#  ('Children', 'NNP'),
#  ('Young', 'NNP'),
#  ('People', 'NNP'),
#  ('’', 'NNP'),
#  ('meeting', 'VBG'),
#  ('agreed', 'VBD'),
#  ('.', '.'),
#  ('Yvonne', 'NNP'),
#  ('MacNamara', 'NNP'),
#  ('Patrick', 'NNP'),
#  ('Kinsella-', 'NNP'),
#  ('Traveller', 'NNP'),
#  ('Movement', 'NNP'),
#  ('The', 'DT'),
#  ('Traveller', 'NNP'),
#  ('Movement', 'NNP'),
#  ('small', 'JJ'),
#  ('charity', 'NN'),
#  ('based', 'VBN'),
#  ('London', 'NNP'),
#  ('national', 'JJ'),
#  ('remit', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('focuses', 'VBZ'),
#  ('building', 'NN'),
#  ('bridges', 'NNS'),
#  ('organisations', 'NNS'),
#  ('working', 'VBG'),
#  ('traveller', 'NN'),
#  ('community', 'NN'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('aim', 'NN'),
#  ('greater', 'JJR'),
#  ('inclusion', 'NN'),
#  (',', ','),
#  ('civic', 'JJ'),
#  ('engagement', 'NN'),
#  ('community', 'NN'),
#  ('cohesion', 'NN'),
#  ('.', '.'),
#  ('Below', 'IN'),
#  ('main', 'JJ'),
#  ('outputs', 'IN'),
#  ('The', 'DT'),
#  ('Traveller', 'NNP'),
#  ('Movement', 'NNP'),
#  ('Equality', 'NNP'),
#  ('Social', 'NNP'),
#  ('Justice', 'NNP'),
#  ('Unit-', 'NNP'),
#  ('3', 'CD'),
#  ('specific', 'JJ'),
#  ('strands', 'NNS'),
#  (':', ':'),
#  ('1', 'CD'),
#  ('.', '.'),
#  ('Early', 'JJ'),
#  ('action', 'NN'),
#  ('capacity', 'NN'),
#  ('building', 'NN'),
#  (',', ','),
#  ('2', 'CD'),
#  ('.', '.'),
#  ('Strategic', 'NNP'),
#  ('litigation', 'NN'),
#  ('e.g', 'NN'),
#  ('.', '.'),
#  ('2015', 'CD'),
#  ('Wetherspoon', 'NNP'),
#  ('litigation', 'NN'),
#  ('case', 'NN'),
#  (',', ','),
#  ('3', 'CD'),
#  ('.', '.'),
#  ('Capacity', 'NN'),
#  ('building', 'VBG'),
#  ('frontline', 'JJ'),
#  ('service', 'NN'),
#  ('providers', 'NNS'),
#  ('Community', 'NNP'),
#  ('led', 'VBD'),
#  ('training', 'VBG'),
#  ('projects-', 'JJ'),
#  ('focus', 'NN'),
#  ('‘', 'NNP'),
#  ('train', 'NN'),
#  ('trainer', 'NN'),
#  ('’', 'JJ'),
#  ('Education', 'NNP'),
#  ('advocacy', 'NN'),
#  ('training-', 'JJ'),
#  ('focuses', 'NNS'),
#  ('school', 'NN'),
#  ('exclusions', 'NNS'),
#  (',', ','),
#  ('bullying', 'VBG'),
#  ('parental', 'JJ'),
#  ('support', 'NN'),
#  ('.', '.'),
#  ('Community', 'NNP'),
#  ('advocacy', 'JJ'),
#  ('Domestic', 'NNP'),
#  ('violence-', 'NN'),
#  ('work', 'NN'),
#  ('done', 'VBN'),
#  ('partnership', 'NN'),
#  ('Solace', 'NNP'),
#  ('Women', 'NNP'),
#  ('’', 'NNP'),
#  ('Aid', 'NNP'),
#  ('provide', 'VBP'),
#  ('advocacy', 'NN'),
#  ('training', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Traveller', 'NNP'),
#  ('Movement', 'NNP'),
#  ('currently', 'RB'),
#  ('running', 'VBG'),
#  ('12', 'CD'),
#  ('week', 'NN'),
#  ('advocacy', 'NN'),
#  ('course', 'NN'),
#  ('women', 'NNS'),
#  ('community', 'NN'),
#  ('.', '.'),
#  ('Policy', 'NNP'),
#  ('&', 'CC'),
#  ('research-', 'JJ'),
#  ('across', 'IN'),
#  ('social', 'JJ'),
#  ('indicators', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Traveller', 'NNP'),
#  ('Movement', 'NNP'),
#  ('currently', 'RB'),
#  ('focusing', 'VBG'),
#  ('criminal', 'JJ'),
#  ('justice', 'NN'),
#  ('health', 'NN'),
#  ('wellbeing', 'VBG'),
#  ('Gypsies', 'NNP'),
#  ('Travellers', 'NNP'),
#  ('criminal', 'JJ'),
#  ('justice', 'NN'),
#  (':', ':'),
#  ('Context', 'NN'),
#  ('There', 'EX'),
#  ('accurate', 'JJ'),
#  ('picture', 'NN'),
#  ('percentage', 'NN'),
#  ('Gypsies', 'VBZ'),
#  ('Travellers', 'NNP'),
#  ('(', '('),
#  ('GRT', 'NNP'),
#  (')', ')'),
#  ('adult', 'NN'),
#  ('prison', 'NN'),
#  ('estate', 'NN'),
#  ('due', 'JJ'),
#  ('different', 'JJ'),
#  ('data', 'NNS'),
#  ('collection', 'NN'),
#  ('monitoring', 'NN'),
#  ('youth', 'NN'),
#  ('justice', 'NN'),
#  ('sector', 'NN'),
#  (',', ','),
#  ('based', 'VBN'),
#  ('2011', 'CD'),
#  ('census', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('figures', 'NNS'),
#  ('still', 'RB'),
#  ('likely', 'JJ'),
#  ('inaccurate', 'JJ'),
#  ('prisoners', 'NNS'),
#  ('may', 'MD'),
#  ('reluctant', 'VB'),
#  ('share', 'NN'),
#  ('ethnicity', 'NN'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('changing', 'VBG'),
#  ('increasing', 'VBG'),
#  ('benefits', 'NNS'),
#  ('self-identifying', 'NN'),
#  ('.', '.'),
#  ('5', 'CD'),
#  ('%', 'NN'),
#  ('adult', 'NN'),
#  ('male', 'JJ'),
#  ('prison', 'NN'),
#  ('estate', 'NN'),
#  ('6', 'CD'),
#  ('%', 'NN'),
#  ('adult', 'NN'),
#  ('female', 'JJ'),
#  ('prison', 'NN'),
#  ('estate', 'NN'),
#  ('Worse', 'NNP'),
#  ('outcomes', 'VBZ'),
#  ('worse', 'JJR'),
#  ('experiences', 'NNS'),
#  ('custody', 'VBP'),
#  ('GRT', 'NNP'),
#  ('less', 'RBR'),
#  ('likely', 'RB'),
#  ('involved', 'JJ'),
#  ('purposeful', 'JJ'),
#  ('activity', 'NN'),
#  ('within', 'IN'),
#  ('adult', 'NN'),
#  ('prison', 'NN'),
#  ('estate', 'NN'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('not', 'RB'),
#  ('fecklessness', 'JJ'),
#  ('unwilling', 'JJ'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('rules', 'NNS'),
#  ('within', 'IN'),
#  ('estate', 'NN'),
#  ('prevent', 'NN'),
#  ('able', 'JJ'),
#  ('work', 'NN'),
#  (':', ':'),
#  ('need', 'VB'),
#  ('Level', 'NNP'),
#  ('2', 'CD'),
#  ('Basic', 'NNP'),
#  ('English', 'JJ'),
#  ('job', 'NN'),
#  ('take', 'VB'),
#  ('part', 'NN'),
#  ('vocational', 'JJ'),
#  ('training', 'NN'),
#  ('.', '.'),
#  ('Furthermore', 'NNP'),
#  (',', ','),
#  ('literacy', 'NN'),
#  ('classes', 'NNS'),
#  ('often', 'RB'),
#  ('not', 'RB'),
#  ('appropriate', 'JJ'),
#  ('adults', 'NNS'),
#  ('.', '.'),
#  ('Below', 'IN'),
#  ('figures', 'NNS'),
#  ('relating', 'VBG'),
#  ('number', 'NN'),
#  ('GRT', 'NNP'),
#  ('children', 'NNS'),
#  ('youth', 'RB'),
#  ('justice', 'NN'),
#  ('system', 'NN'),
#  ('.', '.'),
#  ('12', 'CD'),
#  ('%', 'NN'),
#  ('Secure', 'NNP'),
#  ('Training', 'NNP'),
#  ('Centres', 'NNP'),
#  ('(', '('),
#  ('15', 'CD'),
#  ('%', 'NN'),
#  ('girls', 'NNS'),
#  (')', ')'),
#  ('7', 'CD'),
#  ('%', 'NN'),
#  ('Young', 'NNP'),
#  ('Offender', 'NNP'),
#  ('Institutions', 'NNP'),
#  ('Numbers', 'NNP'),
#  ('almost', 'RB'),
#  ('certainly', 'RB'),
#  ('higher-', 'JJ'),
#  ('example', 'NN'),
#  ('Keppel', 'NNP'),
#  ('Unit', 'NNP'),
#  ('vulnerable', 'JJ'),
#  ('boys', 'NNS'),
#  ('Wetherby', 'NNP'),
#  ('estimated', 'VBD'),
#  ('17', 'CD'),
#  ('%', 'NN'),
#  ('population', 'NN'),
#  ('come', 'VBN'),
#  ('traveller', 'NNP'),
#  ('community', 'NN'),
#  ('The', 'DT'),
#  ('2011', 'CD'),
#  ('census', 'NN'),
#  ('included', 'VBD'),
#  ('GRT', 'NNP'),
#  ('category', 'NN'),
#  ('first', 'JJ'),
#  ('time', 'NN'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('estimated', 'VBD'),
#  ('55,000', 'CD'),
#  ('people', 'NNS'),
#  ('UK', 'NNP'),
#  ('come', 'VBP'),
#  ('background', 'NN'),
#  ('(', '('),
#  ('although', 'IN'),
#  ('figure', 'NN'),
#  ('likely', 'JJ'),
#  ('lot', 'NN'),
#  ('higher', 'JJR'),
#  (')', ')'),
#  ('.', '.'),
#  ('Regardless', 'NNP'),
#  (',', ','),
#  ('clear', 'JJ'),
#  ('GRT', 'NNP'),
#  ('population', 'NN'),
#  ('overrepresented', 'VBD'),
#  ('custodial', 'JJ'),
#  ('system', 'NN'),
#  ('.', '.'),
#  ('As', 'RB'),
#  ('well', 'RB'),
#  ('overrepresented', 'VBN'),
#  (',', ','),
#  ('GRT', 'NNP'),
#  ('community', 'NN'),
#  ('also', 'RB'),
#  ('overlooked', 'VBD'),
#  ('reporting', 'NN'),
#  ('.', '.'),
#  ('No', 'DT'),
#  ('mention', 'NN'),
#  ('Charlie', 'NNP'),
#  ('Taylor', 'NNP'),
#  ('review', 'NN'),
#  ('youth', 'RB'),
#  ('justice-', 'JJ'),
#  ('despite', 'IN'),
#  ('input', 'JJ'),
#  ('community', 'NN'),
#  ('report', 'NN'),
#  ('No', 'DT'),
#  ('mention', 'NN'),
#  ('initial', 'JJ'),
#  ('findings', 'NNS'),
#  ('Lammy', 'NNP'),
#  ('Review-', 'NNP'),
#  ('despite', 'IN'),
#  ('input', 'NN'),
#  ('community', 'NN'),
#  ('report', 'NN'),
#  ('No', 'DT'),
#  ('mention', 'NN'),
#  ('Clinks/Lord', 'NNP'),
#  ('Farmer', 'NNP'),
#  ('Review', 'NNP'),
#  ('No', 'NNP'),
#  ('mention', 'NN'),
#  ('latest', 'JJS'),
#  ('Sentencing', 'VBG'),
#  ('Guidelines', 'NNP'),
#  ('No', 'NNP'),
#  ('mention', 'NN'),
#  ('(', '('),
#  ('far', 'RB'),
#  (')', ')'),
#  ('criminalisation', 'NN'),
#  ('children', 'NNS'),
#  ('care', 'NN'),
#  ('Reduced', 'NNP'),
#  ('emphasis', 'NN'),
#  ('latest', 'JJS'),
#  ('Children', 'NNP'),
#  ('Custody', 'NNP'),
#  ('The', 'DT'),
#  ('Traveller', 'NNP'),
#  ('Movement', 'NNP'),
#  ('hopeful', 'JJ'),
#  ('GRT', 'NNP'),
#  ('background', 'NN'),
#  ('included', 'VBD'),
#  ('sentencing', 'VBG'),
#  ('guidelines', 'NNS'),
#  ('sooner', 'RBR'),
#  ('rather', 'RB'),
#  ('later', 'RB'),
#  ('.', '.'),
#  ('Below', 'IN'),
#  ('shared', 'VBN'),
#  ('characteristics', 'NNS'),
#  ('within', 'IN'),
#  ('community', 'NN'),
#  ('Mental', 'NNP'),
#  ('health', 'NN'),
#  ('issues', 'NNS'),
#  ('&', 'CC'),
#  ('vulnerability', 'NN'),
#  ('self-harm-', 'JJ'),
#  ('GRT', 'NNP'),
#  ('community', 'NN'),
#  ('2-3x', 'CD'),
#  ('likely', 'JJ'),
#  ('self-harm', 'JJ'),
#  ('average', 'JJ'),
#  ('UK', 'NNP'),
#  ('citizen', 'NN'),
#  ('Learning', 'NNP'),
#  ('difficulties-', 'JJ'),
#  ('highest', 'JJS'),
#  ('SEN', 'JJ'),
#  ('rates', 'NNS'),
#  ('ethnic', 'JJ'),
#  ('minority', 'NN'),
#  ('groups', 'NNS'),
#  ('Traumatic', 'NNP'),
#  ('life', 'NN'),
#  ('experiences', 'NNS'),
#  (':', ':'),
#  ('Loss', 'NNP'),
#  (',', ','),
#  ('neglect', 'JJ'),
#  ('abuse-', 'JJ'),
#  ('increasing', 'VBG'),
#  ('prevalence', 'NN'),
#  ('substance', 'NN'),
#  ('abuse', 'NN'),
#  ('(', '('),
#  ('40', 'CD'),
#  ('%', 'NN'),
#  ('YOI', 'NNP'),
#  ('drug', 'NN'),
#  (')', ')'),
#  ('–', 'VBZ'),
#  ('alcoholism', 'NN'),
#  ('shown', 'VBN'),
#  ('coping', 'VBG'),
#  ('mechanism', 'NN'),
#  (';', ':'),
#  ('10-12', 'JJ'),
#  ('lower', 'JJR'),
#  ('life', 'NN'),
#  ('expectancy', 'NN'),
#  ('&', 'CC'),
#  ('high', 'JJ'),
#  ('suicide', 'NN'),
#  ('rate', 'NN'),
#  ('means', 'VBZ'),
#  ('loss', 'NN'),
#  ('parent', 'NN'),
#  ('common', 'JJ'),
#  (';', ':'),
#  ('infant', 'JJ'),
#  ('mortality', 'NN'),
#  ('rate', 'NN'),
#  ('higher', 'JJR'),
#  ('–loss', 'IN'),
#  ('siblings', 'NNS'),
#  (';', ':'),
#  ('high', 'JJ'),
#  ('prevalence', 'NN'),
#  ('DV', 'NNP'),
#  ('(', '('),
#  ('61', 'CD'),
#  ('%', 'NN'),
#  ('Gypsy', 'NNP'),
#  ('81', 'CD'),
#  ('%', 'NN'),
#  ('Irish', 'NNP'),
#  ('Traveller', 'NNP'),
#  (')', ')'),
#  ('Local', 'NNP'),
#  ('authority', 'NN'),
#  ('care-', 'RB'),
#  ('47', 'CD'),
#  ('%', 'NN'),
#  ('children', 'NNS'),
#  ('community', 'NN'),
#  ('secure', 'VBP'),
#  ('training', 'NN'),
#  ('centres', 'NNS'),
#  ('care', 'VBP'),
#  ('.', '.'),
#  ('Negative', 'JJ'),
#  ('experience', 'NN'),
#  ('authority-', 'JJ'),
#  ('Traveller', 'NNP'),
#  ('Movement', 'NNP'),
#  ('’', 'NNP'),
#  ('research', 'NN'),
#  ('suggests', 'VBZ'),
#  ('98', 'CD'),
#  ('%', 'NN'),
#  ('experienced', 'JJ'),
#  ('discrimination', 'NN'),
#  ('ethnicity', 'NN'),
#  (';', ':'),
#  ('exclusion', 'NN'),
#  ('discriminatory', 'NN'),
#  ('(', '('),
#  ('perceived', 'VBN'),
#  (')', ')'),
#  ('policing', 'VBG'),
#  ('=', 'JJ'),
#  ('distrust', 'NN'),
#  ('.', '.'),
#  ('Overrepresented', 'NNP'),
#  ('&', 'CC'),
#  ('Overlooked', 'NNP'),
#  (':', ':'),
#  ('Gypsy', 'NNP'),
#  ('Traveller', 'NNP'),
#  ('Roma', 'NNP'),
#  ('children', 'NNS'),
#  ('youth', 'RB'),
#  ('justice', 'NN'),
#  ('system', 'NN'),
#  ('The', 'DT'),
#  ('report', 'NN'),
#  ('foreword', 'NN'),
#  ('written', 'VBN'),
#  ('Kate', 'NNP'),
#  ('Green', 'NNP'),
#  ('MP', 'NNP'),
#  (',', ','),
#  ('also', 'RB'),
#  ('helped', 'VBD'),
#  ('publicise', 'VB'),
#  ('report', 'NN'),
#  ('initiate', 'NN'),
#  ('Westminster', 'NNP'),
#  ('Hall', 'NNP'),
#  ('debate', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('report', 'NN'),
#  ('’', 'NNP'),
#  ('primary', 'JJ'),
#  ('aim', 'NN'),
#  ('get', 'VB'),
#  ('ethnic', 'JJ'),
#  ('monitoring', 'NN'),
#  ('GRT', 'NNP'),
#  ('community', 'NN'),
#  ('youth', 'NNP'),
#  ('justice', 'NN'),
#  ('system', 'NN'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('help', 'NN'),
#  ('address', 'VB'),
#  ('issue', 'NN'),
#  ('children', 'NNS'),
#  ('falling', 'VBG'),
#  ('along', 'JJ'),
#  ('way', 'NN'),
#  ('unmet', 'JJ'),
#  ('mental', 'JJ'),
#  ('health', 'NN'),
#  ('needs', 'NNS'),
#  ('.', '.'),
#  ('Secure', 'VB'),
#  ('Training', 'VBG'),
#  ('Centres-', 'NNP'),
#  ('statistics', 'NNS'),
#  ('young', 'JJ'),
#  ('gypsies/travellers', 'NNS'),
#  ('Local', 'JJ'),
#  ('authority', 'NN'),
#  ('care', 'NN'),
#  (':', ':'),
#  ('47', 'CD'),
#  ('%', 'NN'),
#  ('local', 'JJ'),
#  ('authority', 'NN'),
#  ('care', 'NN'),
#  ('(', '('),
#  ('compared', 'VBN'),
#  ('37', 'CD'),
#  ('%', 'NN'),
#  ('non-GRT', 'JJ'),
#  (')', ')'),
#  ('Found', 'NNP'),
#  ('significantly', 'RB'),
#  ('difficult', 'JJ'),
#  ('maintain', 'VBP'),
#  ('contact', 'JJ'),
#  ('support', 'NN'),
#  ('networks-', 'JJ'),
#  ('60', 'CD'),
#  ('%', 'NN'),
#  ('said', 'VBD'),
#  ('easy', 'JJ'),
#  ('compared', 'VBN'),
#  ('90', 'CD'),
#  ('%', 'NN'),
#  ('non-GRT', 'JJ'),
#  ('Twice', 'NNP'),
#  ('likely', 'JJ'),
#  ('report', 'NN'),
#  ('unmet', 'VBD'),
#  ('health', 'NN'),
#  ('needs', 'NNS'),
#  ('Significantly', 'NNP'),
#  ('less', 'RBR'),
#  ('likely', 'JJ'),
#  ('report', 'NN'),
#  ('learning', 'VBG'),
#  ('skills', 'NNS'),
#  ('jobs', 'NNS'),
#  ('’', 'VBP'),
#  ('like', 'IN'),
#  ('future', 'JJ'),
#  ('Safety', 'NN'),
#  (':', ':'),
#  ('3x', 'CD'),
#  ('greater', 'JJR'),
#  ('reports', 'NNS'),
#  ('physical', 'JJ'),
#  ('abuse', 'NN'),
#  ('staff', 'NN'),
#  ('&', 'CC'),
#  ('5x', 'CD'),
#  ('likely', 'JJ'),
#  ('report', 'NN'),
#  ('property', 'NN'),
#  ('taken', 'VBN'),
#  ('children', 'NNS'),
#  ('Young', 'NNP'),
#  ('Offenders', 'NNPS'),
#  ('Institutions-', 'NNP'),
#  ('statistics', 'NNS'),
#  ('young', 'JJ'),
#  ('gypsies/travellers', 'NNS'),
#  ('33', 'CD'),
#  ('%', 'NN'),
#  ('local', 'JJ'),
#  ('authority', 'NN'),
#  ('care', 'NN'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('decreased', 'VBD'),
#  ('44', 'CD'),
#  ('%', 'NN'),
#  ('2015', 'CD'),
#  ('still', 'RB'),
#  ('high', 'JJ'),
#  ('Less', 'NNP'),
#  ('likely', 'JJ'),
#  ('say', 'VBP'),
#  ('first', 'JJ'),
#  ('time', 'NN'),
#  ('custody-', 'JJ'),
#  ('51', 'CD'),
#  ('%', 'NN'),
#  ('compared', 'VBN'),
#  ('61', 'CD'),
#  ('%', 'NN'),
#  ('-', ':'),
#  ('also', 'RB'),
#  ('31', 'CD'),
#  ('%', 'NN'),
#  ('sentenced', 'VBD'),
#  ('12', 'CD'),
#  ('months', 'NNS'),
#  ('<', 'RB'),
#  ('40', 'CD'),
#  ('%', 'NN'),
#  ('problem', 'NN'),
#  ('drugs', 'NNS'),
#  ('first', 'RB'),
#  ('arrived', 'VBD'),
#  ('A', 'DT'),
#  ('quarter', 'NN'),
#  ('reported', 'VBD'),
#  ('mental', 'JJ'),
#  ('health', 'NN'),
#  ('issues', 'NNS'),
#  ('–', 'VBP'),
#  ('less', 'JJR'),
#  ('half', 'NN'),
#  ('said', 'VBD'),
#  ('helped', 'JJ'),
#  ('issue', 'VB'),
#  ('55', 'CD'),
#  ('%', 'NN'),
#  ('14', 'CD'),
#  ('younger', 'JJR'),
#  ('last', 'JJ'),
#  ('school', 'NN'),
#  ('&', 'CC'),
#  ('84', 'CD'),
#  ('%', 'NN'),
#  ('excluded', 'VBD'),
#  ('Less', 'NNP'),
#  ('likely', 'RB'),
#  ('know', 'VBP'),
#  ('contact', 'VB'),
#  ('help', 'NN'),
#  ('opening', 'VBG'),
#  ('bank', 'NN'),
#  ('account', 'NN'),
#  ('continuing', 'VBG'),
#  ('health', 'NN'),
#  ('services', 'NNS'),
#  ('released', 'VBD'),
#  ('One', 'CD'),
#  ('ten', 'JJ'),
#  ('people', 'NNS'),
#  ('community', 'NN'),
#  ('Young', 'NNP'),
#  ('Offenders', 'NNP'),
#  ('Institutions', 'NNP'),
#  ('child', 'NN'),
#  ('.', '.'),
#  ('What', 'WP'),
#  ('next', 'IN'),
#  ('?', '.'),
#  ('How', 'NNP'),
#  ('services', 'NNS'),
#  ('improved', 'VBN'),
#  ('?', '.'),
#  ('Good', 'JJ'),
#  ('practice', 'NN'),
#  ('guide-', 'JJ'),
#  ('particular', 'JJ'),
#  ('custody', 'NN'),
#  ('ineffective', 'JJ'),
#  (',', ','),
#  ('prevalence', 'NN'),
#  ('reoffending', 'VBG'),
#  ('overall', 'JJ'),
#  ('lack', 'NN'),
#  ('support', 'NN'),
#  ('.', '.'),
#  ('Culturally', 'NNP'),
#  ('appropriate', 'JJ'),
#  ('learning', 'VBG'),
#  ('resources-', 'JJ'),
#  ('programme', 'NN'),
#  ('aimed', 'VBN'),
#  ('GRT', 'NNP'),
#  ('(', '('),
#  ('perhaps', 'RB'),
#  ('emphasis', 'RB'),
#  ('trade', 'NN'),
#  (')', ')'),
#  ('non-literate', 'JJ'),
#  ('offenders', 'NNS'),
#  ('would', 'MD'),
#  ('beneficial', 'VB'),
#  ('.', '.'),
#  ('This', 'DT'),
#  ('twin-pronged', 'JJ'),
#  ('approach', 'NN'),
#  ('mentoring', 'NN'),
#  ('.', '.'),
#  ('Support', 'NNP'),
#  ('GRT', 'NNP'),
#  ('groups', 'NNS'),
#  (':', ':'),
#  ('lessons', 'NNS'),
#  ('adult', 'VBP'),
#  ('estate', 'NN'),
#  ('implemented', 'VBN'),
#  ('.', '.'),
#  ('Support', 'NNP'),
#  ('groups', 'NNS'),
#  ('provide', 'VBP'),
#  ('safe-spaces', 'NNS'),
#  ('create', 'VBP'),
#  ('positive', 'JJ'),
#  ('outlook', 'NN'),
#  ('.', '.'),
#  ('Improve', 'NNP'),
#  ('participation', 'NN'),
#  ('education', 'NN'),
#  ('purposeful', 'JJ'),
#  ('activity', 'NN'),
#  ('Summary', 'NNP'),
#  ('support', 'NN'),
#  ('needed', 'VBD'),
#  ('beyond', 'IN'),
#  ('custody', 'NN'),
#  ('Overall', 'JJ'),
#  ('analysis', 'NN'),
#  ('children', 'NNS'),
#  ('go', 'VBP'),
#  ('custody', 'NN'),
#  ('needed', 'VBN'),
#  ('.', '.'),
#  ('Is', 'VBZ'),
#  ('education/training', 'VBG'),
#  ('?', '.'),
#  ('Early', 'JJ'),
#  ('intervention', 'NN'),
#  ('building', 'NN'),
#  ('community', 'NN'),
#  ('advocacy', 'NN'),
#  ('also', 'RB'),
#  ('important', 'JJ'),
#  ('.', '.'),
#  ('Notwithstanding', 'VBG'),
#  ('GRT', 'JJ'),
#  ('culture', 'NN'),
#  ('needs', 'VBZ'),
#  ('understood', 'JJ'),
#  ('respected', 'VBN'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ('real', 'JJ'),
#  ('need', 'NN'),
#  ('targeted', 'VBD'),
#  ('funding', 'VBG'),
#  ('initiatives', 'NNS'),
#  ('advocacy', 'JJ'),
#  ('support', 'NN'),
#  ('(', '('),
#  ('marginalised', 'JJ'),
#  ('communities', 'NNS'),
#  (')', ')'),
#  ('.', '.'),
#  ('There', 'EX'),
#  ('often', 'RB'),
#  ('language', 'NN'),
#  ('cultural', 'JJ'),
#  ('barriers', 'NNS'),
#  ('preventing', 'VBG'),
#  ('GRT', 'NNP'),
#  ('community', 'NN'),
#  ('accessing', 'VBG'),
#  ('standard', 'JJ'),
#  ('advocacy', 'NN'),
#  ('services', 'NNS'),
#  ('.', '.'),
#  ('For', 'IN'),
#  ('instance', 'NN'),
#  ('families', 'NNS'),
#  ('contact', 'VBP'),
#  ('GRT', 'NNP'),
#  ('organisations', 'NNS'),
#  ('care', 'VBP'),
#  ('proceedings', 'NNS'),
#  ('already', 'RB'),
#  ('‘', 'VBP'),
#  ('11th', 'CD'),
#  ('hour', 'NN'),
#  ('’', 'NN'),
#  ('.', '.'),
#  ('Once', 'RB'),
#  ('children', 'NNS'),
#  ('placed', 'VBD'),
#  ('foster', 'NN'),
#  ('care', 'NN'),
#  (',', ','),
#  ('likely', 'RB'),
#  ('placed', 'VBN'),
#  ('adoption', 'NN')]

# %%
def lemmize(text):
    wordnet_lemmatizer = WordNetLemmatizer()
    finalStemmed = []
    for w in text : 
        allInfo = w
        word = allInfo[0]
        tag = allInfo[1]
        stemmedWord = ""
        try:
            stemmedWord = wordnet_lemmatizer.lemmatize(word,get_wordnet_pos(tag))
            finalStemmed.append((stemmedWord,w[1][0]))
        except Exception:
            finalStemmed.append((w[0],w[1][0]))     
    return finalStemmed

# %%
print(lemmize(textPOS[:100]))
# Out:
# [('child', 'N'), ('young', 'J'), ('people', 'N'), ('network', 'N'), ('18.05.2017', 'C'), ('london', 'N'), ('funders', 'N'), ('participant', 'N'), ('deborah', 'V'), ('meyer', 'N'), ('big', 'J'), ('lottery', 'N'), ('fund', 'N'), ('toyin', 'N'), ('ogundana', 'J'), ('caf', 'N'), ('venturesome', 'N'), ('daisy', 'N'), ('ryan', 'J'), ('henry', 'N'), ('smith', 'N'), ('charity', 'N'), ('erik', 'J'), ('mesel', 'N'), ('john', 'N'), ('lyon', 'N'), ("'s", 'P'), ('charity', 'N'), ('sharon', 'N'), ('long', 'R'), ('partnership', 'N'), ('young', 'J'), ('london', 'N'), ('mihai', 'J'), ('calin', 'N'), ('bica', 'N'), ('rom', 'N'), ('support', 'N'), ('group', 'N'), ('gaba', 'V'), ('smolinska-', 'J'), ('rom', 'N'), ('support', 'N'), ('group', 'N'), ('poffley', 'V'), ('victoria', 'N'), ('cousin', 'N'), ('safer', 'V'), ('london', 'J'), ('foundation', 'N'), ('cara', 'N'), ('whelan', 'N'), ('save', 'V'), ('child', 'N'), ('emma', 'V'), ('hale', 'J'), ('sir', 'N'), ('john', 'N'), ('ca', 'N'), ("'s", 'P'), ('foundation', 'N'), ('rachel', 'N'), ('earnshaw', 'R'), ('big', 'J'), ('give', 'N'), ('ciaran', 'N'), ('rafferty', 'N'), ('city', 'N'), ('bridge', 'N'), ('trust', 'N'), ('jenny', 'N'), ('oppenheimer', 'N'), ('pilgrim', 'N'), ('trust', 'N'), ('patrick', 'N'), ('kinsella', 'N'), ('traveller', 'N'), ('movement', 'N'), ('yvonne', 'N'), ('macnamara', 'N'), ('traveller', 'N'), ('movement', 'N'), ('flora', 'N'), ('ward', 'V'), ('youth', 'N'), ('music', 'N'), ('attendance', 'N'), ('geraldine', 'N'), ('tovey', 'I'), ('london', 'J'), ('funders', 'N'), ('david', 'V'), ('warner', 'J'), ('london', 'J'), ('funders', 'N'), ('welcome', 'J'), ('apology', 'N'), ('absence', 'N'), ('ciaran', 'N'), ('welcome', 'V')]

# %%
print(keppels_files_pdf[84])
pdf = PyPDF2.PdfFileReader(keppels_files_pdf[4],'rb')
pdf.getNumPages()
print(pdf.getPage(6).extractText())

# %%
pdf = PyPDF2.PdfFileReader("files/Keppel\\2017-DeepwaterPoster-D6-Ads.pdf",'rb')
print(pdf.getPage(0).extractText())

# %%
def countPDF(pdf,comp):
    count = 0
    result = []
    count = 0
    try:
        doc = PyPDF2.PdfFileReader(pdf,'r')
        index = doc.getNumPages()
        #print(index)
        if(index<100):
            for i in range(0,index):
                txt = doc.getPage(i).extractText()
                allS = txt.split(' ')
                for s in allS:
                    if(comp in s.lower()):
                        count+=1
    except:
        print("COULD NOT OPEN THE PDF ", pdf)
    return count

# %%
def mapperOpener(path):
    mapping = []
    with open(path, 'r') as csvfile:
        spamreader = csv.reader(csvfile,delimiter='|')
        for row in spamreader:
            mapping.append((row[0],row[1],row[2]))
    return mapping

# %%
filesMap = mapperOpener("submission_mapper.csv")

# %%
keppel = 'files/Keppel\\'
prudential = 'files/Prudential\\'
## Checked all are included in the if clauses
def fromMapToOpener(fileMap):
    for line in fileMap:
        count = 0
        ID = line[0]
        fileName = line[1]
        compName = line[2]
        ##pdf
        if(fileName.endswith('pdf')):
            if(compName == 'Keppel'):
                count = countPDF(keppel+fileName,'keppel')
            else:
                count = countPDF(prudential+fileName,'prudential')
        ##doc
        elif((fileName.endswith('doc') or fileName.endswith('docx'))):
             if(compName == 'Keppel'):
                countDoc(getText(keppel+fileName))
        ##excel
        elif(fileName.endswith('xls') or fileName.endswith('xlsx')):
            count += 1
        else:
             print('WRONG')
        print(fileName,count)

# %%
fromMapToOpener(filesMap)
# Out:
# WRONG
# filename 0
# JD_KDCREIT%20-%20Asset%20Mgt_Analyst_2017.pdf 10
# 5f4c7c69049c32670176932fd1d305271372e912.pdf 43
# 20100319_214216_BN4_F6859A6425BC8427482576EB00331260.1.pdf 20
# businessassociatelist--1-.xlsx 1
# PdfReadWarning: Xref table not zero-indexed. ID numbers for objects will be corrected. [pdf.py:1736]
# WSHA2011%20Winners_8%20Aug.pdf 24
# sin63964.doc 1
# KOMTechnology%20StrategyJuly03v3.pdf 21
# Keppel%20REIT_AR2016.pdf 0
# pre_13sep2010_n2.pdf 4
# Dec06.xls 1
# 04_April_2016.pdf 388
# bmap_text_8.doc 1
# KCL_AR2014_Operating_Financial_Review.pdf 281
# 02_February_2016.pdf 381
# nfholdings_1721961_0917.xlsx 1
# standcontributorspre1999.xls 1
# KLL_SR2011.pdf 0
# grants.xls 1
# inSYNC_ecopy.pdf 1
# Dr%20Rob%20Kelly%20-%20Keppel%20Fels%20Loadout%20Speech.doc 1
# Ads.pdf 4
# Handout-oct14-final-version-17-10-2014.docx 1
# REP-1437137611.pdf 655
# PALS-Bar-Ops-Pilipinas-Must-Read-Cases-CIVIL-2015.docx 1
# om10_mar%20april%202010.pdf 261
# 2016%20jan-february%20issue.pdf 419
# Allianz-Hongkou-SOHO_EN.pdf 12
# 53_11338.pdf 0
# nfa_list.xls 1
# STAT%20379s08%20study%20guide.doc 1
# Classifying-Serial-Sexual-Murder-Murderers-An-Attempt-to-Validate-Keppel-and-Walters-1999-Model.pdf 71
# TPG500%20Loadout%20press%20release%20July%202004.doc 1
# Submission+to+the+Human+Rights+and+Equal+Opportunity+Commission.doc 1
# BDO-LTNCTD-Due-2020-Final-OC.pdf 0
# intergraph_marineeditioninsight.pdf 26
# CYP%20Meeting%20May%202017docx.docx 1
# Rule_Ann-Kiss_Me_Kill_Me.doc 1
# KCL_AR2015_Keppel_Group_Boards_of_Directors.pdf 30
# CG2011.pdf 23
# B4_2_TUAN-Loh-Ah_Keppel-Seghers-Engineering-Singapore.pdf 7
# KCL.pdf 758
# River-Oaks-IL-14-_-CHR-Library-Books1.xlsx 1
# How%20to%20complete%20the%20PIF%20guidance%20draft%20v0.5.doc 1
# April.pdf 418
# Baku-inauguration-panels.pdf 28
# 2015%20nov-december%20issue.pdf 432
# kepinfratrust-dbs-170417.pdf 22
# Keppel%20Shipyard%20Brochure.pdf 27
# 299295322.pdf 345
